# %%
import os

# %%
list_dir=os.listdir('Resources')
list_dir
# Out:
# ['S&P500.xlsx',
#  '.DS_Store',
#  'Oil2010-2023.xlsx',
#  'training_data.csv',
#  'gold2010-2023.xlsx',
#  '.ipynb_checkpoints',
#  'soy1.xlsx']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# oil FTXN
# gold GLD
# s&p SPY
# soy ^SPGSSOTR

# %%
#Data Source
import yfinance as yf

#Interval required 1 minute
data = yf.download(tickers=['SPY', 'FTXN', 'GLD', '^SPGSSOTR'], period='2y', interval='1h')
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data
# Out:
#                            Adj Close                                       \
#                                 FTXN         GLD         SPY    ^SPGSSOTR
# Datetime
# 2021-05-25 12:30:00-04:00  16.629999  177.699997  419.095001  5522.761230
# 2021-05-25 13:30:00-04:00  16.559999  177.699997  418.329987  5555.814941
# 2021-05-25 14:30:00-04:00  16.540001  177.819000  418.440002  5555.814941
# 2021-05-25 15:30:00-04:00  16.514999  177.929993  418.250000  5552.142090
# 2021-05-26 09:30:00-04:00  16.565001  178.350006  418.731110  5537.454102
# ...                              ...         ...         ...          ...
# 2023-05-24 15:30:00-04:00  26.236200  181.979996  411.079987  6065.387207
# 2023-05-25 09:30:00-04:00  25.719999  181.029602  413.130005  6072.001953
# 2023-05-25 10:30:00-04:00  25.670000  180.740005  413.600006  6070.856934
# 2023-05-25 11:30:00-04:00  25.650000  180.549896  414.176697  5990.717773
# 2023-05-25 12:30:00-04:00  25.730000  180.539993  413.725006  6060.553223
#
#                                Close                                       \
#                                 FTXN         GLD         SPY    ^SPGSSOTR
# Datetime
# 2021-05-25 12:30:00-04:00  16.629999  177.699997  419.095001  5522.761230
# 2021-05-25 13:30:00-04:00  16.559999  177.699997  418.329987  5555.814941
# 2021-05-25 14:30:00-04:00  16.540001  177.819000  418.440002  5555.814941
# 2021-05-25 15:30:00-04:00  16.514999  177.929993  418.250000  5552.142090
# 2021-05-26 09:30:00-04:00  16.565001  178.350006  418.731110  5537.454102
# ...                              ...         ...         ...          ...
# 2023-05-24 15:30:00-04:00  26.236200  181.979996  411.079987  6065.387207
# 2023-05-25 09:30:00-04:00  25.719999  181.029602  413.130005  6072.001953
# 2023-05-25 10:30:00-04:00  25.670000  180.740005  413.600006  6070.856934
# 2023-05-25 11:30:00-04:00  25.650000  180.549896  414.176697  5990.717773
# 2023-05-25 12:30:00-04:00  25.730000  180.539993  413.725006  6060.553223
#
#                                 High              ...         Low  \
#                                 FTXN         GLD  ...         SPY
# Datetime                                          ...
# 2021-05-25 12:30:00-04:00  16.679899  177.720001  ...  418.380005
# 2021-05-25 13:30:00-04:00  16.590000  177.910004  ...  418.220001
# 2021-05-25 14:30:00-04:00  16.575001  177.884995  ...  417.796906
# 2021-05-25 15:30:00-04:00  16.514999  177.949997  ...  417.619995
# 2021-05-26 09:30:00-04:00  16.639999  178.610001  ...  417.760010
# %%
training_df.to_csv('Resources/training_data.csv')

# %%
training_df=pd.read_csv('Resources/training_data.csv', parse_dates=True, index_col='Datetime')
training_df.head()
# Out:
#                                 FTXN         GLD         SPY    ^SPGSSOTR
# Datetime
# 2021-05-25 12:30:00-04:00  16.629999  177.699997  419.095001  5522.761230
# 2021-05-25 13:30:00-04:00  16.559999  177.699997  418.329987  5555.814941
# 2021-05-25 14:30:00-04:00  16.540001  177.819000  418.440002  5555.814941
# 2021-05-25 15:30:00-04:00  16.514999  177.929993  418.250000  5552.142090
# 2021-05-26 09:30:00-04:00  16.565001  178.350006  418.731110  5537.454102

# %%
training_df['SPY_T+1']=training_df['SPY'].shift(1)
training_df=training_df.dropna()
training_df.head()
# Out:
#                                 FTXN         GLD         SPY    ^SPGSSOTR  \
# Datetime
# 2021-05-25 13:30:00-04:00  16.559999  177.699997  418.329987  5555.814941
# 2021-05-25 14:30:00-04:00  16.540001  177.819000  418.440002  5555.814941
# 2021-05-25 15:30:00-04:00  16.514999  177.929993  418.250000  5552.142090
# 2021-05-26 09:30:00-04:00  16.565001  178.350006  418.731110  5537.454102
# 2021-05-26 10:30:00-04:00  16.690001  178.190002  418.980011  5576.017090
#
#                               SPY_T+1
# Datetime
# 2021-05-25 13:30:00-04:00  419.095001
# 2021-05-25 14:30:00-04:00  418.329987
# 2021-05-25 15:30:00-04:00  418.440002
# 2021-05-26 09:30:00-04:00  418.250000
# 2021-05-26 10:30:00-04:00  418.731110

# %%
training_df[['FTXN', 'GLD', 'SPY', '^SPGSSOTR']].plot()
plt.grid()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
y=training_df['SPY_T+1']
X=training_df.drop(columns=['SPY_T+1'])

# %%
train_idx=int(len(training_df)*.8)

X_train=X.iloc[: train_idx]
X_test=X.iloc[train_idx: ]
y_train=y.iloc[: train_idx]
y_test=y.iloc[train_idx: ]

# %%
scaler=StandardScaler()
scaler.fit(X_train)

X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)
X_scaled=scaler.transform(X)

# %%
fig, ax=plt.subplots()
pd.DataFrame(X_scaled, columns=X.columns).set_index(X.index).plot(figsize=(15, 5), ax=ax)
ax.vlines(X.iloc[train_idx].name, ymin=-3, ymax=3, color='red')
plt.grid()

# %%
lr=LinearRegression()
lr.fit(X_train_scaled, y_train)
print(f'Train score: {lr.score(X_train_scaled, y_train)}')
print(f'Test score: {lr.score(X_test_scaled, y_test)}')
# Out:
# Train score: 0.9959682101331678
# Test score: 0.9751210257020352

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(X_train_scaled, y_train)
print(f'Train score: {rfr.score(X_train_scaled, y_train)}')
print(f'Test score: {rfr.score(X_test_scaled, y_test)}')
# Out:
# Train score: 0.9993432730542295
# Test score: 0.948956989935132

# %%
import pickle

with open('scaler.pkl', 'wb') as f: 
    pickle.dump(scaler, f)

# %%
with open('lr.pkl', 'wb') as f: 
    pickle.dump(lr, f)
